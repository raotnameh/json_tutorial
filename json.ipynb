# %%
# !ls
# Out:
# data.json  json.ipynb  middle_square_algo  NLP_Tutorial

# %% [markdown]
# # https://realpython.com/python-json/

# %% [markdown]
# # What is JSON?
#
# JSON stands for JavaScript Object Notation
#
# JSON is a lightweight data-interchange format
#
# JSON is "self-describing" and easy to understand
#
# JSON is language independent *
#
#
# *
# JSON uses JavaScript syntax, but the JSON format is text only.
# Text can be read and used as a data format by any programming language.

# %% [markdown]
# # Exchanging Data
#
# When exchanging data between a browser and a server, the data can only be text.
#
# JSON is text, and we can convert any JavaScript object into JSON, and send JSON to the server.
#
# We can also convert any JSON received from the server into JavaScript objects.
#
# This way we can work with the data as JavaScript objects, with no complicated parsing and translations.

# %% [markdown]
# # The community at large adopted JSON because it’s easy for both humans and machines to create and understand.

# %% [markdown]
# # What is json?

# %%
data = {
    "firstName": "Jane",
    "lastName": "Doe",
    "hobbies": ["running", "sky diving", "singing"],
    "age": 35,
    "children": [
        {
            "firstName": "Alice",
            "age": 6
        },
        {
            "firstName": "Bob",
            "age": 8
        }
    ]
}
data
# Out:
# {'firstName': 'Jane',
#  'lastName': 'Doe',
#  'hobbies': ['running', 'sky diving', 'singing'],
#  'age': 35,
#  'children': [{'firstName': 'Alice', 'age': 6},
#   {'firstName': 'Bob', 'age': 8}]}

# %%
import json

# %% [markdown]
# # Serialized the data

# %%
data_json_s = json.dumps(data)
data_json_s
# Out:
# '{"firstName": "Jane", "lastName": "Doe", "hobbies": ["running", "sky diving", "singing"], "age": 35, "children": [{"firstName": "Alice", "age": 6}, {"firstName": "Bob", "age": 8}]}'

# %% [markdown]
# # Deserialized the data

# %%
data = json.loads(data_json_s)

# %%
data
# Out:
# {'firstName': 'Jane',
#  'lastName': 'Doe',
#  'hobbies': ['running', 'sky diving', 'singing'],
#  'age': 35,
#  'children': [{'firstName': 'Alice', 'age': 6},
#   {'firstName': 'Bob', 'age': 8}]}

# %% [markdown]
# # json read and write functions

# %%
def write_json(addr,data):
    with open(str(addr), "w") as write_file:
        json.dump(data, write_file)

# %%
def read_json(addr):
    with open(str(addr), "r") as read_file:
        data = json.load(read_file)
    return data

# %%
# !ls
# Out:
# data.json  json.ipynb  middle_square_algo  NLP_Tutorial

# %%
write_json("m.json",data)

# %%
data = read_json("m.json")

# %%
data
# Out:
# {'firstName': 'Jane',
#  'lastName': 'Doe',
#  'hobbies': ['running', 'sky diving', 'singing'],
#  'age': 35,
#  'children': [{'firstName': 'Alice', 'age': 6},
#   {'firstName': 'Bob', 'age': 8}]}

# %% [markdown]
# # Real world data
#
#
# .

# %%
data = read_json('data.json')

# %%
data
# Out:
# {'conformsTo': 'https://project-open-data.cio.gov/v1.1/schema',
#  'describedBy': 'https://project-open-data.cio.gov/v1.1/schema/catalog.json',
#  '@context': 'https://project-open-data.cio.gov/v1.1/schema/catalog.jsonld',
#  '@type': 'dcat:Catalog',
#  'dataset': [{'@type': 'dcat:Dataset',
#    'title': 'SBA IT Policy Archive',
#    'description': 'A list of all public documents relating to SBA IT policy.',
#    'modified': '2015-08-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-OCIO-2015-08-002',
#    'landingPage': 'https://www.sba.gov/about-sba/sba-performance/open-government/digital-sba/digital-strategy/it-policy-archive',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Asghar Noor',
#     'hasEmail': 'mailto:asghar.noor@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'https://www.sba.gov/about-sba/sba-performance/open-government/digital-sba/digital-strategy/it-policy-archive',
#      'title': 'SBA IT Policy Archive'},
#     {'@type': 'dcat:Distribution',
#      'mediaType': 'application/zip',
#      'title': 'SBA IT Policy Archive Policy Zip',
#      'downloadURL': 'https://inventory.data.gov/dataset/5e3c4309-c3ce-43f8-91c7-d02e7b8cffb8/resource/ab01e3f4-1d92-4f60-9a7d-6ee9f65ee3f5/download/sbaitpolicyarchive.zip'}],
#    'keyword': ['Agency IT Policy Archive', 'SBA IT Policy Archive'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:000']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Bureau IT Leadership Directory',
#    'description': 'A directory of all SBA officials with the title of CIO or duties of a CIO.',
#    'modified': '2015-08-15',
#    'accessLevel': 'public',
#    'identifier': 'SBA-OCIO-2015-08-001',
#    'landingPage': 'https://www.sba.gov/about-sba/sba-performance/open-government/digital-sba/digital-strategy/it-leadership-directory',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Asghar Noor',
#     'hasEmail': 'mailto:asghar.noor@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'https://www.sba.gov/about-sba/sba-performance/open-government/digital-sba/digital-strategy/it-leadership-directory',
#      'title': 'Bureau IT Leadership Directory'},
#     {'@type': 'dcat:Distribution',
#      'mediaType': 'application/json',
#      'title': 'Bureau IT Leadership Directory Json',
#      'downloadURL': 'https://inventory.data.gov/dataset/c2d67157-e134-4837-a13e-3d92fc7a7d40/resource/3838ba7a-5802-448a-8321-69558e3a2b4d/download/bureaudirectory.json'}],
#    'keyword': ['Bureau IT Leadership Directory'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:000']},
#   {'@type': 'dcat:Dataset',
#    'title': 'CIO Governance Board Membership List',
#    'description': 'Information about SBA CIO’s membership in governance boards.',
#    'modified': '2015-08-30',
#    'accessLevel': 'public',
#    'identifier': 'SBA-OCIO-2015-08-003',
#    'landingPage': 'https://www.sba.gov/about-sba/sba-performance/open-government/digital-sba/digital-strategy/governance-board-membership',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Asghar Noor',
#     'hasEmail': 'mailto:asghar.noor@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'https://www.sba.gov/about-sba/sba-performance/open-government/digital-sba/digital-strategy/governance-board-membership',
#      'title': 'CIO Governanace Board'},
#     {'@type': 'dcat:Distribution',
#      'mediaType': 'application/json',
#      'title': 'CIO Governance Board Membership List',
#      'downloadURL': 'https://inventory.data.gov/dataset/93f8387a-c85d-467d-9410-52e16e544a86/resource/b55a6342-78fb-4de7-9654-ee0ac95583fe/download/governanceboardschema.json'}],
#    'keyword': ['CIO role on program governance boards'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:000']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Dynamic Small Business Search (DSBS)',
#    'description': 'The Small Business Administration maintains the Dynamic Small Business Search (DSBS) database. As a small business registers in the System for Award Management, there is an opportunity to fill out the small business profile. The information provided populates DSBS. DSBS is another tool contracting officers use to identify potential small business contractors for upcoming contracting opportunities. Small businesses can also use DSBS to identify other small businesses for teaming and joint venturing.',
#    'modified': '2013-12-12',
#    'accessLevel': 'public',
#    'identifier': 'SBA-GCDB-2013-11-001',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'William A. Adams',
#     'hasEmail': 'mailto:William.adams@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'http://dsbs.sba.gov/dsbs/search/dsp_dsbs.cfm',
#      'title': 'DSBS'}],
#    'keyword': ['Business name', 'Company name', 'Organization name'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:000'],
#    'theme': ['search tool',
#     'user controlled',
#     'dynamic',
#     'business information',
#     'SBA registered']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Small Business Administration (SBA) Loan Program Performance- Total Recovery Amount for Guarantied Programs by Program',
#    'description': 'Reflects total recoveries for the four large guarantied programs and an aggregate total for all of the small guarantied programs.',
#    'modified': '2000-01-01',
#    'accessLevel': 'public',
#    'identifier': 'SBA-CFO-2015-05-005',
#    'landingPage': 'https://www.sba.gov/about-sba/sba-performance/performance-budget-finances/small-business-administration-sba-loan-program-performance',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'accrualPeriodicity': 'R/P3M',
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Lala Lunstrum',
#     'hasEmail': 'mailto:lala.lunstrum@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'Total Recovery Amount for Guarantied Programs by Program',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/WDS_Table6_RecoveryAmount_Report.pdf'}],
#    'keyword': ['Loan',
#     'Loan Balance',
#     'Loan Performance',
#     'Loan Recoveries',
#     'Loan Recovery',
#     'Recoveries'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:002']},
#   {'@type': 'dcat:Dataset',
#    'title': 'U.S. Small Business HUBZone Qualitfied Census Tracts',
#    'description': 'HUBZone Designated Area based on the Department of Housing and Urban Development (HUD) designated Qualified Census Tracts (QCTs).  Watch HUBZone mini-primer on Understanding HUBZone Designations for additional information.',
#    'modified': '2013-05-24',
#    'accessLevel': 'public',
#    'identifier': 'SBA-GCDB-2015-02-001',
#    'landingPage': 'https://www.sba.gov/content/hubzone-maps',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'accrualPeriodicity': 'R/P10Y',
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Kimberly A. Russell',
#     'hasEmail': 'mailto:Kimberly.Russell@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'Qualified Census Tracts in PDF',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/2015_TractDesignations.pdf'},
#     {'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'Qualified Census Tracts in excel',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/2015_TractDesignations.xlsx'}],
#    'keyword': ['Government Contracting',
#     'HUBZone',
#     'Historically Underutilized Business Zone',
#     'QCT',
#     'Qualified Census Tracts'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:006'],
#    'theme': ['HUBZone Maps']},
#   {'@type': 'dcat:Dataset',
#    'title': 'U.S. Small Business HUBZone Base Closure Areas',
#    'description': 'HUBZone Qualitified Base Closure Areas - the lands within the boundaries of a military installation that was closed through a privatization process under the Federal Government authority.',
#    'modified': '2014-12-17',
#    'accessLevel': 'public',
#    'identifier': 'SBA-GCDB-2015-02-002',
#    'landingPage': 'https://www.sba.gov/content/hubzone-maps',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Kimberly A. Russell',
#     'hasEmail': 'mailto:Kimberly.Russell@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'HUBZone -Qualified Base Closure Areas in PDF',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/2015_BaseClosureAreas.pdf'},
#     {'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'HUBZone -Qualified Base Closure Areas in Excel',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/2015_BaseClosureAreas.xlsx'}],
#    'keyword': ['BRAC',
#     'Base Closure',
#     'Government Contracting',
#     'HUBZone',
#     'Historically Underutilized Business Zone',
#     'QBA'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:006'],
#    'theme': ['HUBZone Maps']},
#   {'@type': 'dcat:Dataset',
#    'title': 'U.S. Small Business HUBZone Qualified Indian Lands',
#    'description': 'HUBZone Qualitified Indian Lands, lands within the boundaries of Indian reservations.',
#    'modified': '2014-01-06',
#    'accessLevel': 'public',
#    'identifier': 'SBA-GCDB-2015-02-004',
#    'landingPage': 'https://www.sba.gov/content/hubzone-maps',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Kimberly A. Russell',
#     'hasEmail': 'mailto:Kimberly.Russell@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'HUBZone - Qualified Indian Lands in PDF',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/2014_QualifiedIndianLands.pdf'},
#     {'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'HUBZone - Qualified Indian Lands in EXCEL',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/2014_QualifiedIndianLands.xlsx'}],
#    'keyword': ['Government Contracting',
#     'HUBZone',
#     'Historically Underutilized Business Zone',
#     'Indian Country',
#     'Indian Reservations',
#     'Native American Land',
#     'Qualified Indian Lands'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:006'],
#    'theme': ['HUBZone Maps']},
#   {'@type': 'dcat:Dataset',
#    'title': 'U.S. Small Business HUBZone Nonmetropolitan Counties',
#    'description': 'HUBZone Qualitified Nonmetropolitan Counties',
#    'modified': '2015-01-01',
#    'accessLevel': 'public',
#    'identifier': 'SBA-GCDB-2015-02-003',
#    'landingPage': 'https://www.sba.gov/content/hubzone-maps',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Kimberly A. Russell',
#     'hasEmail': 'mailto:Kimberly.Russell@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'HUBZone Qualified Non-metropolitan Counties in PDF',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/January2015_CountyDesignations.pdf'},
#     {'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'HUBZone Qualified Non-metropolitan Counties in Excel',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/January2015_CountyDesignations.xlsx'}],
#    'keyword': ['Government Contracting',
#     'HUBZone',
#     'Historically Underutilized Business Zone',
#     'Non-metropolitan County',
#     'Nonmetropolitan County',
#     'QNMC'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:006'],
#    'theme': ['HUBZone Maps']},
#   {'@type': 'dcat:Dataset',
#    'title': "Office of Advocacy's News Update File",
#    'description': 'This is an xml news update file to inform the public about recent regulatory alerts, Advocacy small business statistics reports, Advocacy small business research reports, and Advocacy regulatory comment letters.',
#    'modified': '2014-08-12',
#    'accessLevel': 'public',
#    'identifier': 'SBA-OD-2014-08-001',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Asghar Noor',
#     'hasEmail': 'mailto:asghar.noor@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'https://www.sba.gov/advocacy/feed#',
#      'format': 'application/rss+xml',
#      'title': 'Regulatory alerts'}],
#    'keyword': ['Advocacy', 'News', 'SBA', 'Update File'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:031'],
#    'theme': ['SBA', 'Advocacy', 'News', 'Update File', 'SBA registered']},
#   {'@type': 'dcat:Dataset',
#    'title': 'RASCO (Recruitment, Assessment, Selection, Credentialing and Onboarding) Tracker',
#    'description': 'RASCO is a place for hiring managers to review status updates of pending recruit actions.',
#    'modified': '2017-02-01',
#    'accessLevel': 'non-public',
#    'identifier': 'SBA-OHRS-2017-02-001',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'rights': 'Data is restricted to only employees of the SBA.',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Trisha Christian',
#     'hasEmail': 'mailto:Trisha.Christian@sba.gov'},
#    'keyword': ['Assessment',
#     'Credentialing',
#     'Onboarding',
#     'Recruitment',
#     'Selection',
#     'Staffing'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:000'],
#    'theme': ['Staffing',
#     'Recruitment',
#     'Assessment',
#     'Selection',
#     'Credentialing',
#     'Onboarding']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA 7a and 504 Loan Data Reports',
#    'description': 'These files include a loan level list of all 7(a) and 504 loans approved since January 1, 1990 as well as the corresponding Data Dictionary. SBA 7(a) and 504 Loan Data Dictionary ,Monthly Report of SBA 7(a) and 504 Loan Data,1990 - 1999 SBA 7a Loan Data , 2000 - Present SBA 7(a) Loan Data and 1990 - Present SBA 504 Loan Data.',
#    'modified': '2016-06-22',
#    'accessLevel': 'public',
#    'identifier': 'SBA-OHA-2016-08-001',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Laura L. Magere',
#     'hasEmail': 'mailto:laura.magere@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'https://www.sba.gov/content/sba-7a-504-loan-data-reports',
#      'title': 'SBA 7a and 504 Loan Data Reports'}],
#    'keyword': ['504 Loan Data Reports', '7a', 'Loan Data Report', 'SBA'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:001']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2011',
#    'description': 'SBA Disaster Loan Data for FY 2011 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2014-10-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2014-11-004',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA_Disaster_Loan_Data_FY_2011',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY11.xlsx'}],
#    'keyword': ['SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2008',
#    'description': 'SBA Disaster Loan Data for FY 2008 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2014-10-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2016-02-001',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA Disaster Loan Data FY 2008',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY08.xlsx'}],
#    'keyword': ['SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2007',
#    'description': 'SBA Disaster Loan Data for FY 2007 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2016-07-25',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2016-11-001',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA Disaster Loan Data 2007',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY07.xlsx'}],
#    'keyword': ['2007',
#     'SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2006',
#    'description': 'SBA Disaster Loan Data for FY 2006 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2016-07-25',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2016-11-002',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA Disaster Loan Data 2006',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY06.xlsx'}],
#    'keyword': ['2006',
#     'SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2005',
#    'description': 'SBA Disaster Loan Data for FY 2005 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2016-07-25',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2016-11-003',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA Disaster Loan Data 2005',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY05.xlsx'}],
#    'keyword': ['2005',
#     'SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2004',
#    'description': 'SBA Disaster Loan Data for FY 2004 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2016-07-25',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2016-11-004',
#    'dataQuality': False,
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA Disaster Loan Data 2004',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY04.xlsx'}],
#    'keyword': ['2004',
#     'SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Network Components & Software Inventory',
#    'description': 'SBA’s Network Components & Software Inventory contains a complete inventory of all devices connected to SBA’s network including workstations, servers, routers, switches, printers, and the software installed on all workstations and servers.',
#    'modified': '2016-11-04',
#    'accessLevel': 'non-public',
#    'identifier': 'SBA-OCIO-2016-11-001',
#    'dataQuality': False,
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'rights': 'The publishing of the data asset cannot be done due to the sensitive nature of the information that is being collected which could pose a security threat if made public',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Kathleen Tindal',
#     'hasEmail': 'mailto:kathleen.tindal@sba.gov'},
#    'keyword': ['Network Inventory', 'SBA'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:000'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2012',
#    'description': 'SBA Disaster Loan Data for FY 2012 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2014-10-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2014-11-005',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA_Disaster_Loan_Data_FY_2012',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY12.xlsx'}],
#    'keyword': ['SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2013',
#    'description': 'SBA Disaster Loan Data for FY2013 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2014-10-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2014-11-003',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA_Disaster_Loan_Data_FY_2013',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY13.xlsx'}],
#    'keyword': ['SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2014',
#    'description': 'SBA Disaster Loan Data for FY2014 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2014-10-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2014-11-002',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA_Disaster_Loan_Data_FY_2014',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY14.xlsx'}],
#    'keyword': ['SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2009',
#    'description': 'SBA Disaster Loan Data for FY2009 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2014-10-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2016-02-002',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA Disaster Loan Data FY 2009',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY09.xlsx'}],
#    'keyword': ['SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2010',
#    'description': 'SBA Disaster Loan Data for FY2010 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2014-10-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2016-02-003',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA Disaster Loan Data FY2010',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY10.xlsx'}],
#    'keyword': ['SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2015',
#    'description': 'SBA Disaster Loan Data for FY2015 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2014-10-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2016-02-004',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA Disaster Loan Data FY2015',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY15.xlsx'}],
#    'keyword': ['SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data FY2016',
#    'description': 'SBA Disaster Loan Data for FY2016 provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2016-10-01',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2017-02-002',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA Disaster Loan Data FY2016',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_FY16.xlsx'}],
#    'keyword': ['SBA',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Disaster Loan Data - Superstorm Sandy',
#    'description': 'SBA Disaster Loan Data for Superstorm Sandy provides verified loss and approved loan amount totals for both home and business disaster loans, segmented by city, county, zip code and state.',
#    'modified': '2014-09-30',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ODA-2014-11-001',
#    'landingPage': 'https://www.sba.gov/content/disaster-loan-data',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Alejandro Contreras',
#     'hasEmail': 'mailto:alejandro.contreras@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#      'title': 'SBA_Disaster_Loan_Data for Superstorm_Sandy',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/articles/SBA_Disaster_Loan_Data_Superstorm_Sandy_0.xlsx'}],
#    'keyword': ['Hurricane Sandy',
#     'SBA',
#     'Superstorm Sandy',
#     'business loan',
#     'disaster assistance',
#     'disaster loan',
#     'disaster recovery',
#     'economic injury',
#     'home loan'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:017'],
#    'theme': ['SBA',
#     'disaster loan',
#     'Hurricane Sandy',
#     'Superstorm Sandy',
#     'disaster assistance',
#     'disaster recovery',
#     'home loan',
#     'business loan',
#     'economic injury']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Emails RSS',
#    'description': 'This RSS feed includes all emails sent from SBA to the public via our GovDelivery email marketing tool.',
#    'modified': '2014-08-12',
#    'accessLevel': 'public',
#    'identifier': 'SBA-OCIO-2014-08-002',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Asghar Noor',
#     'hasEmail': 'mailto:asghar.noor@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'https://public.govdelivery.com/accounts/USSBA/feed.rss',
#      'format': 'application/rss+xml',
#      'title': 'SBA Emails Feed'}],
#    'keyword': ['Emails', 'SBA'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:000'],
#    'theme': ['email', 'tool', 'SBA', 'Emails', 'SBA registered']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA Enterprise Datasets',
#    'description': 'Provides a list of all the datasets available in the Enterprise Data Inventory for the Small Business Administration.',
#    'modified': '2015-02-23',
#    'accessLevel': 'public',
#    'identifier': 'SBA-EDI-2015-02-001',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Asghar Noor',
#     'hasEmail': 'mailto:asghar.noor@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/json',
#      'title': 'Data.json',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/data.json'}],
#    'keyword': ['JSON', 'data', 'dataset', 'public', 'sba', 'small business'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:000']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA FITARA Implementation Plan',
#    'description': 'Federal Information Technology Acquisition Reform Act (FITARA) enhances the  responsibility and authority of agency CIOs so as to increase their efficiency in managing and overseeing IT resources and assets. These responsibilities and authorities include, but are not limited to: IT portfolio review; budget formulation and approval of IT budgets; CIO appointing authority; enhanced transparency and risk management of IT investments; IT workforce planning; strategic sourcing; and consistency in reporting to strengthen accountability and manage cost, schedule, and performance measures for IT programs. \r\n\r\nSBA’s FITARA Implementation Plan describes the policies, processes, and guidance that require updates or revisions to meet Office of Management and Budget (OMB) objectives and comply with FITARA requirements.',
#    'modified': '2016-02-18',
#    'accessLevel': 'public',
#    'identifier': 'SBA-OCIO-2016-02-001',
#    'landingPage': 'https://www.sba.gov/content/sba-fitara-implementation-plan',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Asghar I. Noor',
#     'hasEmail': 'mailto:ANoor@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'https://www.sba.gov/about-sba/sba-performance/open-government/digital-sba/digital-strategy/sba-fitara-implementation-plan',
#      'title': 'SBA FITARA Implementation Plan'},
#     {'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'sba-fitara-implementation-plan',
#      'downloadURL': 'https://inventory.data.gov/dataset/15c174dc-d228-41d2-a5d3-3a7731be34a1/resource/f0f88de0-f2a5-487b-bb51-5d504a193457/download/sba-fitara-implementation-plan.pdf'}],
#    'keyword': ['FITARA',
#     'Federal Information Technology Acquisition Reform',
#     'SBA'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:031']},
#   {'@type': 'dcat:Dataset',
#    'title': 'SBA IT Reform Cost Savings/Avoidance',
#    'description': 'IT Reform Cost Savings/Avoidance for the Small Business Administration provides information about cost savings and/or avoidances realized from IT reforms.  Cost savings/avoidance are reported per OMB Circular A-131. Cost savings represent reductions in actual expenditures below the projected level of costs to achieve a specific objective. Cost avoidance represents an action taken in the immediate time frame that will decrease costs in the future. The file contains only PortfolioStat and FDCCI savings/avoidances reported by SBA in OMB’s Information Technology Oversight and Reform  (ITOR) report to date.',
#    'modified': '2015-11-15',
#    'accessLevel': 'public',
#    'identifier': 'SBA-OCIO-2015-11-001',
#    'landingPage': 'https://www.sba.gov/content/it-reform-cost-savings',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Asghar I. Noor',
#     'hasEmail': 'mailto:ANoor@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/json',
#      'title': 'SBA IT Reform Cost Savings/Avoidance',
#      'downloadURL': 'https://inventory.data.gov/dataset/fb14072a-44fb-485a-bd67-f8950444896d/resource/a25af1dc-a56a-42e2-a5d1-cda287546361/download/costsavings.json'},
#     {'@type': 'dcat:Distribution',
#      'accessURL': 'https://www.sba.gov/about-sba/sba-performance/open-government/digital-sba/digital-strategy/it-reform-cost-savings',
#      'title': 'SBA Cost Saving'}],
#    'keyword': ['Avoidance',
#     'Cost',
#     'Cost Avoidance',
#     'Cost Savings',
#     'IT Reform',
#     'Portfoliostat',
#     'SBA',
#     'Savings'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:000']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Small Business Administration (SBA) Loan Program Performance- Charge Off Rates as a Percent of Unpaid Principal Balance (UPB) Amount by Program',
#    'description': 'Reflects charge off rates, as a percent of the UPB amounts, at the end of the fiscal year for the major loan programs and aggregate totals for the small direct and guarantied programs.',
#    'modified': '2014-12-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-CFO-2015-05-002',
#    'landingPage': 'https://www.sba.gov/about-sba/sba-performance/performance-budget-finances/small-business-administration-sba-loan-program-performance',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'accrualPeriodicity': 'R/P3M',
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Lala Lunstrum',
#     'hasEmail': 'mailto:lala.lunstrum@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'Charge Off Rates as a Percent of Unpaid Principal Balance (UPB) Amount by Program',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/WDS_Table9_ChargeOffRates_Report.pdf'}],
#    'keyword': ['Balance',
#     'Charge',
#     'Charge Off',
#     'Loan',
#     'Loan Balance',
#     'Loan Performance',
#     'Loans',
#     'UPB',
#     'Unpaid Principal Balance'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:002']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Small Business Administration (SBA) Loan Program Performance- Post-Charge Off Recovery Amount by Program',
#    'description': 'Reflects total recoveries for the four large guarantied programs and an aggregate total for all of the small guarantied programs.',
#    'modified': '2014-12-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-CFO-2015-05-004',
#    'landingPage': 'https://www.sba.gov/about-sba/sba-performance/performance-budget-finances/small-business-administration-sba-loan-program-performance',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'accrualPeriodicity': 'R/P3M',
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Lala Lunstrum',
#     'hasEmail': 'mailto:lala.lunstrum@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'Post-Charge Off Recovery Amount by Program',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/WDS_Table7_PostChargeOffRecovery_Report.pdf'}],
#    'keyword': ['Charge off',
#     'Charge-off',
#     'Loan',
#     'Loan Balance',
#     'Loan Performance',
#     'Loan Recovery',
#     'Post Charge off',
#     'Recovery'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:002']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Small Business Administration (SBA) Loan Program Performance- Post-Charge Off Recovery Rates by Program',
#    'description': 'Reflects total post-charge off recovery rates, as a percent of the amounts charged off by charge off year, for the major loan programs and aggregate totals by charge off year for the small direct and guarantied programs.',
#    'modified': '2014-12-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-CFO-2015-05-011',
#    'landingPage': 'https://www.sba.gov/about-sba/sba-performance/performance-budget-finances/small-business-administration-sba-loan-program-performance',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'TBD',
#     'hasEmail': 'mailto:TBD@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'https://www.sba.gov/sites/default/files/WDS_Table11_PostChargeOffRecoveryRates_Report.pdf',
#      'title': 'Post-Charge Off Recovery Rates by Program'}],
#    'keyword': ['Charge-Offs',
#     'Loan',
#     'Loan Balance',
#     'Loan Performance',
#     'Post Charge Off',
#     'Recoveries',
#     'Recovery amounts'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:002']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Small Business Administration (SBA) Loan Program Performance- Purchase Rates as a Percent of Unpaid Principal Balance (UPB)',
#    'description': 'Reflects purchases, as a percent of the active UPB amounts, as of the end of the fiscal year for the major loan programs and aggregate totals for the small direct and guarantied programs',
#    'modified': '2014-12-31',
#    'accessLevel': 'public',
#    'identifier': 'SBA-CFO-2015-05-003',
#    'landingPage': 'https://www.sba.gov/about-sba/sba-performance/performance-budget-finances/small-business-administration-sba-loan-program-performance',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'accrualPeriodicity': 'R/P3M',
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Lala Lunstrum',
#     'hasEmail': 'mailto:lala.lunstrum@sba.gov'},
# ...
#      'downloadURL': 'https://www.sba.gov/sites/default/files/Size_Standards_Table.pdf'}],
#    'keyword': ['SBA', 'Size', 'small business', 'standards'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:012'],
#    'theme': ['SBA', 'Size', 'standards', 'small business', 'SBA registered']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Small Business Lending Institutions in Alabama - 2010-2011',
#    'description': 'Small Business Lending in the United States, published by the SBA’s Office of Advocacy annually since 1994, looks at small business lending locally and nationally using two types of data supplied by depository institutions to their respective regulating agencies—Call Reports for June 2011 and Community Reinvestment Act (CRA) reports for 2010. The study includes cooperative banks in addition to existing depository institutions and gives a brief review on the institution lending patterns in 2010 and 2011. The rankings and performance of these lenders are summarized and organized by state/ territory, loan size, number of loans, and asset size of the institution. The Small Business Lending tables use the call report data to rank all lenders for the state of Alabama.',
#    'modified': '2011-06-01',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ADVO-2015-11-059',
#    'landingPage': 'https://www.sba.gov/content/small-business-lending-united-states-2010-2011',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'isPartOf': 'SBA-ADVO-2015-11-057',
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Victoria K. Williams',
#     'hasEmail': 'mailto:Victoria.Williams@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'Small Business Lending Institutions in Alabama for 2010-2011',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/bk_12al.pdf'}],
#    'keyword': ['2010',
#     '2011',
#     'Alabama',
#     'Lending',
#     'SBA',
#     'Territory',
#     'annual banking',
#     'asset size',
#     'institutions lending',
#     'loan size',
#     'number of loans',
#     'state'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:031']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Small Business Lending Institutions in Alaska - 2010-2011',
#    'description': 'Small Business Lending in the United States, published by the SBA’s Office of Advocacy annually since 1994, looks at small business lending locally and nationally using two types of data supplied by depository institutions to their respective regulating agencies—Call Reports for June 2011 and Community Reinvestment Act (CRA) reports for 2010. The study includes cooperative banks in addition to existing depository institutions and gives a brief review on the institution lending patterns in 2010 and 2011. The rankings and performance of these lenders are summarized and organized by state/ territory, loan size, number of loans, and asset size of the institution. The Small Business Lending tables use the call report data to rank all lenders for the state of Alaska.',
#    'modified': '2011-06-01',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ADVO-2015-11-060',
#    'landingPage': 'https://www.sba.gov/content/small-business-lending-united-states-2010-2011',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'isPartOf': 'SBA-ADVO-2015-11-057',
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Victoria K. Williams',
#     'hasEmail': 'mailto:Victoria.Williams@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'Small Business Lending Institutions in Alaska for 2010-2011',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/bk_12ak.pdf'}],
#    'keyword': ['2010',
#     '2011',
#     'Alaska',
#     'Lending',
#     'SBA',
#     'Territory',
#     'annual banking',
#     'asset size',
#     'institutions lending',
#     'loan size',
#     'number of loans',
#     'state'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:031']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Small Business Lending Institutions in Arizona - 2010-2011',
#    'description': 'Small Business Lending in the United States, published by the SBA’s Office of Advocacy annually since 1994, looks at small business lending locally and nationally using two types of data supplied by depository institutions to their respective regulating agencies—Call Reports for June 2011 and Community Reinvestment Act (CRA) reports for 2010. The study includes cooperative banks in addition to existing depository institutions and gives a brief review on the institution lending patterns in 2010 and 2011. The rankings and performance of these lenders are summarized and organized by state/ territory, loan size, number of loans, and asset size of the institution. The Small Business Lending tables use the call report data to rank all lenders for the state of Arizona.',
#    'modified': '2011-06-01',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ADVO-2015-11-061',
#    'landingPage': 'https://www.sba.gov/content/small-business-lending-united-states-2010-2011',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'isPartOf': 'SBA-ADVO-2015-11-057',
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Victoria K. Williams',
#     'hasEmail': 'mailto:Victoria.Williams@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'Small Business Lending Institutions in Arizona for 2010-2011',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/bk_12az.pdf'}],
#    'keyword': ['2010',
#     '2011',
#     'Arizona',
#     'Lending',
#     'SBA',
#     'Territory',
#     'annual banking',
#     'asset size',
#     'institutions lending',
#     'loan size',
#     'number of loans',
#     'state'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:031']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Small Business Lending Institutions in Arkansas - 2010-2011',
#    'description': 'Small Business Lending in the United States, published by the SBA’s Office of Advocacy annually since 1994, looks at small business lending locally and nationally using two types of data supplied by depository institutions to their respective regulating agencies—Call Reports for June 2011 and Community Reinvestment Act (CRA) reports for 2010. The study includes cooperative banks in addition to existing depository institutions and gives a brief review on the institution lending patterns in 2010 and 2011. The rankings and performance of these lenders are summarized and organized by state/ territory, loan size, number of loans, and asset size of the institution. The Small Business Lending tables use the call report data to rank all lenders for the state of Arkansas.',
#    'modified': '2011-06-01',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ADVO-2015-11-062',
#    'landingPage': 'https://www.sba.gov/content/small-business-lending-united-states-2010-2011',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'isPartOf': 'SBA-ADVO-2015-11-057',
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Victoria K. Williams',
#     'hasEmail': 'mailto:Victoria.Williams@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'Small Business Lending Institutions in Arkansas for 2010-2011',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/bk_12ar.pdf'}],
#    'keyword': ['2010',
#     '2011',
#     'Arkansas',
#     'Lending',
#     'SBA',
#     'Territory',
#     'annual banking',
#     'asset size',
#     'institutions lending',
#     'loan size',
#     'number of loans',
#     'state'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:031']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Small Business Lending Institutions in California - 2010-2011',
#    'description': 'Small Business Lending in the United States, published by the SBA’s Office of Advocacy annually since 1994, looks at small business lending locally and nationally using two types of data supplied by depository institutions to their respective regulating agencies—Call Reports for June 2011 and Community Reinvestment Act (CRA) reports for 2010. The study includes cooperative banks in addition to existing depository institutions and gives a brief review on the institution lending patterns in 2010 and 2011. The rankings and performance of these lenders are summarized and organized by state/ territory, loan size, number of loans, and asset size of the institution. The Small Business Lending tables use the call report data to rank all lenders for the state of California.',
#    'modified': '2011-06-01',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ADVO-2015-11-063',
#    'landingPage': 'https://www.sba.gov/content/small-business-lending-united-states-2010-2011',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'isPartOf': 'SBA-ADVO-2015-11-057',
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Victoria K. Williams',
#     'hasEmail': 'mailto:Victoria.Williams@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'applications/pdf',
#      'title': 'Small Business Lending Institutions in California for 2010-2011',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/bk_12ca.pdf'}],
#    'keyword': ['2010',
#     '2011',
#     'California',
#     'Lending',
#     'SBA',
#     'Territory',
#     'annual banking',
#     'asset size',
#     'institutions lending',
#     'loan size',
#     'number of loans',
#     'state'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:031']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Small Business Lending Institutions in Colorado - 2010-2011',
#    'description': 'Small Business Lending in the United States, published by the SBA’s Office of Advocacy annually since 1994, looks at small business lending locally and nationally using two types of data supplied by depository institutions to their respective regulating agencies—Call Reports for June 2011 and Community Reinvestment Act (CRA) reports for 2010. The study includes cooperative banks in addition to existing depository institutions and gives a brief review on the institution lending patterns in 2010 and 2011. The rankings and performance of these lenders are summarized and organized by state/ territory, loan size, number of loans, and asset size of the institution. The Small Business Lending tables use the call report data to rank all lenders for the state of Colorado.',
#    'modified': '2011-06-01',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ADVO-2015-11-064',
#    'landingPage': 'https://www.sba.gov/content/small-business-lending-united-states-2010-2011',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'isPartOf': 'SBA-ADVO-2015-11-057',
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Victoria K. Williams',
#     'hasEmail': 'mailto:Victoria.Williams@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'Small Business Lending Institutions in Colorado for 2010-2011',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/bk_12co.pdf'}],
#    'keyword': ['2010',
#     '2011',
#     'Colorado',
#     'Lending',
#     'SBA',
#     'Territory',
#     'annual banking',
#     'asset size',
#     'institutions lending',
#     'loan size',
#     'number of loans',
#     'state'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:031']},
#   {'@type': 'dcat:Dataset',
#    'title': 'Small Business Lending Institutions in Connecticut - 2010-2011',
#    'description': 'Small Business Lending in the United States, published by the SBA’s Office of Advocacy annually since 1994, looks at small business lending locally and nationally using two types of data supplied by depository institutions to their respective regulating agencies—Call Reports for June 2011 and Community Reinvestment Act (CRA) reports for 2010. The study includes cooperative banks in addition to existing depository institutions and gives a brief review on the institution lending patterns in 2010 and 2011. The rankings and performance of these lenders are summarized and organized by state/ territory, loan size, number of loans, and asset size of the institution. The Small Business Lending tables use the call report data to rank all lenders for the state of Connecticut.',
#    'modified': '2011-06-01',
#    'accessLevel': 'public',
#    'identifier': 'SBA-ADVO-2015-11-065',
#    'landingPage': 'https://www.sba.gov/content/small-business-lending-united-states-2010-2011',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'isPartOf': 'SBA-ADVO-2015-11-057',
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Victoria K. Williams',
#     'hasEmail': 'mailto:Victoria.Williams@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'mediaType': 'application/pdf',
#      'title': 'Small Business Lending Institutions in Connecticut for 2010-2011',
#      'downloadURL': 'https://www.sba.gov/sites/default/files/files/bk_12ct.pdf'}],
#    'keyword': ['2010',
#     '2011',
#     'Connecticut',
#     'Lending',
#     'SBA',
#     'Territory',
#     'annual banking',
#     'asset size',
#     'institutions lending',
#     'loan size',
#     'number of loans',
#     'state'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:031']},
#   {'@type': 'dcat:Dataset',
#    'title': 'State Licenses & Permits',
#    'description': 'Starting a business? Confused about whether you need a business license or permit?\r\n \r\nVirtually every business needs some form of license or permit to operate legally. However, licensing and permit requirements vary depending on the type of business you are operating, where it’s located, and what government rules apply.\r\n \r\nTo help you identify the specific licenses or permits your business may need, simply select a state from the list below to learn about specific license and permit requirements in the area where your business is located.',
#    'modified': '2015-01-01',
#    'accessLevel': 'public',
#    'identifier': 'SBA-OCIO-2015-05-001',
#    'license': 'http://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Asghar Noor',
#     'hasEmail': 'mailto:asghar.noor@sba.gov'},
#    'distribution': [{'@type': 'dcat:Distribution',
#      'accessURL': 'https://www.sba.gov/content/what-state-licenses-and-permits-does-your-business-need',
#      'format': 'API'}],
#    'keyword': ['Licenses', 'Permits', 'Small Business', 'State'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:001']},
#   {'@type': 'dcat:Dataset',
#    'title': 'The Developer Software Whitelist Approved by ARB',
#    'description': 'This dataset is the developer software whitelist approved by the Agency’s Architecture Review Board(ARB)',
#    'modified': '2015-12-17',
#    'accessLevel': 'restricted public',
#    'identifier': 'SBA-ARB-2017-05-002',
#    'license': 'https://www.usa.gov/publicdomain/label/1.0/',
#    'publisher': {'@type': 'org:Organization',
#     'name': 'U.S. Small Business Administration'},
#    'contactPoint': {'@type': 'vcard:Contact',
#     'fn': 'Asghar Noor',
#     'hasEmail': 'mailto:Asghar.noor@sba.gov'},
#    'keyword': ['ARB', 'Developer', 'SBA', 'Software Whitelist'],
#    'bureauCode': ['028:00'],
#    'programCode': ['028:000']}]}

# %%
data.keys()
# Out:
# dict_keys(['conformsTo', 'describedBy', '@context', '@type', 'dataset'])

# %%
data['conformsTo']
# Out:
# 'https://project-open-data.cio.gov/v1.1/schema'

# %% [markdown]
# # visualizing data in pandas

# %%
import pandas as pd

# %%
data_pd = pd.DataFrame(data['dataset'])

# %%
data_pd.head()
# Out:
#           @type accessLevel accrualPeriodicity bureauCode  \
# 0  dcat:Dataset      public                NaN   [028:00]
# 1  dcat:Dataset      public                NaN   [028:00]
# 2  dcat:Dataset      public                NaN   [028:00]
# 3  dcat:Dataset      public                NaN   [028:00]
# 4  dcat:Dataset      public              R/P3M   [028:00]
#
#                                         contactPoint dataQuality  \
# 0  {'@type': 'vcard:Contact', 'fn': 'Asghar Noor'...         NaN
# 1  {'@type': 'vcard:Contact', 'fn': 'Asghar Noor'...         NaN
# 2  {'@type': 'vcard:Contact', 'fn': 'Asghar Noor'...         NaN
# 3  {'@type': 'vcard:Contact', 'fn': 'William A. A...         NaN
# 4  {'@type': 'vcard:Contact', 'fn': 'Lala Lunstru...         NaN
#
#                                          description  \
# 0  A list of all public documents relating to SBA...
# 1  A directory of all SBA officials with the titl...
# 2  Information about SBA CIO’s membership in gove...
# 3  The Small Business Administration maintains th...
# 4  Reflects total recoveries for the four large g...
#
#                                         distribution            identifier  \
# 0  [{'@type': 'dcat:Distribution', 'accessURL': '...  SBA-OCIO-2015-08-002
# 1  [{'@type': 'dcat:Distribution', 'accessURL': '...  SBA-OCIO-2015-08-001
# 2  [{'@type': 'dcat:Distribution', 'accessURL': '...  SBA-OCIO-2015-08-003
# 3  [{'@type': 'dcat:Distribution', 'accessURL': '...  SBA-GCDB-2013-11-001
# 4  [{'@type': 'dcat:Distribution', 'mediaType': '...   SBA-CFO-2015-05-005
#
#   isPartOf                                            keyword  \
# 0      NaN  [Agency IT Policy Archive, SBA IT Policy Archive]
# 1      NaN                   [Bureau IT Leadership Directory]
# 2      NaN            [CIO role on program governance boards]
# 3      NaN   [Business name, Company name, Organization name]
# 4      NaN  [Loan, Loan Balance, Loan Performance, Loan Re...
#
#                                          landingPage  \
# 0  https://www.sba.gov/about-sba/sba-performance/...
# 1  https://www.sba.gov/about-sba/sba-performance/...
# 2  https://www.sba.gov/about-sba/sba-performance/...
# 3                                                NaN
# 4  https://www.sba.gov/about-sba/sba-performance/...
#
#                                       license    modified programCode  \
# 0  http://www.usa.gov/publicdomain/label/1.0/  2015-08-31   [028:000]
# 1  http://www.usa.gov/publicdomain/label/1.0/  2015-08-15   [028:000]
# 2  http://www.usa.gov/publicdomain/label/1.0/  2015-08-30   [028:000]
# 3  http://www.usa.gov/publicdomain/label/1.0/  2013-12-12   [028:000]
# 4  http://www.usa.gov/publicdomain/label/1.0/  2000-01-01   [028:002]
#
#                                            publisher rights  \
# 0  {'@type': 'org:Organization', 'name': 'U.S. Sm...    NaN
# 1  {'@type': 'org:Organization', 'name': 'U.S. Sm...    NaN
# 2  {'@type': 'org:Organization', 'name': 'U.S. Sm...    NaN
# 3  {'@type': 'org:Organization', 'name': 'U.S. Sm...    NaN
# 4  {'@type': 'org:Organization', 'name': 'U.S. Sm...    NaN
#
#                                                theme  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  [search tool, user controlled, dynamic, busine...
# 4                                                NaN
#
#                                                title
# 0                              SBA IT Policy Archive
# 1                     Bureau IT Leadership Directory
# 2               CIO Governance Board Membership List
# 3               Dynamic Small Business Search (DSBS)
# 4  Small Business Administration (SBA) Loan Progr...

# %% [markdown]
# ## We can have any valid PYTHON data type as a json

# %%
kfio = {'hemant': [{"gaurav":[[1,2,3,4]]}]}

# %%
kfio
# Out:
# {'hemant': [{'gaurav': [[1, 2, 3, 4]]}]}

# %%
write_json("f.json",kfio)

# %%
read_json("f.json")
# Out:
# {'hemant': [{'gaurav': [[1, 2, 3, 4]]}]}

# %% [markdown]
# # use IJSON for dataset
